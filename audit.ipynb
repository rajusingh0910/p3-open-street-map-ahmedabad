# %%
'''
In order to start the data wrangling process, the following modules in python will be essential.
'''

import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

# opening file in filename
filename = open("ahmedabad.osm", "r")

# %%
# count the number of unique element types

'''
First we will create an empty dictionary and then parse through the tags to count them.
'''

tags = {}

for event, elem in ET.iterparse(filename):
    if elem.tag in tags: 
        tags[elem.tag] += 1
    else:
        tags[elem.tag] = 1
        
pprint.pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 2288,
#  'nd': 639811,
#  'node': 550820,
#  'osm': 1,
#  'relation': 510,
#  'tag': 99409,
#  'way': 82308}

# %%
# lets look at number of unique users having edited the map for Phoenix Arizona

'''
By creating the process_map function, we start by creating an empty set, then parse through elements in the file. 
If the element attribute "uid" is found, it is added to the set. All we have to do then is to call the length of the set in order
to find the number of unique users.
'''

filename = open("ahmedabad.osm", "r")

def process_map(filename):
    users = set()
    for i, element in ET.iterparse(filename):
        for elem in element:
            if 'uid' in elem.attrib:
                users.add(elem.attrib['uid'])
    return users

users = process_map(filename)
len(users)
# Out:
# 368

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE_sample = "ahmedabad.osm"
regex = re.compile(r'\b\S+\.?', re.IGNORECASE)

expected = ["Ahmedabad", "Road", "NR", "Avenue", "SBK", "Gandhi", "Bridge", "Society"] #expected names in the dataset

mapping = {"ahmedabad": "Ahmedabad",
           "Ahmadabad": "Ahmedabad",
           "Ahamadabad": "Ahmedabad",
           "Nr.": "NR",
           "Ave.": "Avenue",
           "sbk": "SBK",
           "gandhi": "Gandhi",
           "bridge": "Bridge",
           "road": "Road",
           "Ft.": "Feet",
           "ft": "Feet",
           "Rd": "Road",
           "Rd.": "Road",
           "rasta": "Road",
           "Roads": "Road",
           "society": "Society",
           "soc.": "Society",
           "Socity": "Society",
           "Gujarat.": "Gujarat,"
            }

# Search string for the regex. If it is matched and not in the expected list then add this as a key to the set.
def audit_street(street_types, street_name): 
    m = regex.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem): # Check if it is a street name
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile): # return the list that satify the above two functions
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street(street_types, tag.attrib['v'])

    return street_types

pprint.pprint(dict(audit(OSMFILE_sample))) # print the existing names

def string_case(s): # change string into titleCase except for UpperCase
    if s.isupper():
        return s
    else:
        return s.title()

# return the updated names
def update_name(name, mapping):
    name = name.split(' ')
    for i in range(len(name)):
        if name[i] in mapping:
            name[i] = mapping[name[i]]
            name[i] = string_case(name[i])
        else:
            name[i] = string_case(name[i])
    
    name = ' '.join(name)
   

    return name

update_street = audit(OSMFILE_sample) 

# print the updated names
for street_type, ways in update_street.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# {'100': set(['100 Ft. Road', '100 ft Road']),
#  '101,': set(['101, Paritosh Building, Usmanpura, Ashram Road']),
#  '120': set(['120 Feet Ring Road']),
#  '132': set(['132 Ft. Ring Road']),
#  '2nd': set(['2nd Floor, Aditya Complex, Opp kasturi Dining Hall, Paldi Cross Road, Paldi',
#              '2nd Floor, Dev Arc Mall, Satellite Rd, Off S.G Highway, Near Iskcon Bridge']),
#  '8': set(['8 aasiyana society jivrajpark nr 132 ring road ahmedabad']),
#  'ACHER': set(['ACHER ROAD']),
#  'ASarwa': set(['ASarwa']),
#  'Adalaj': set(['Adalaj -sarkhej road']),
#  'Ahmedabad-Kalol': set(['Ahmedabad-Kalol Highway']),
#  'Airport': set(['Airport Road']),
#  'Akhabarnagar': set(['Akhabarnagar Circle']),
#  'Akshar': set(['Akshar Avenue']),
#  'Anand': set(['Anand nagar road']),
#  'Ashram': set(['Ashram Road']),
#  'Asmita': set(['Asmita Society']),
#  'B/H': set(['B/H AryaVilla']),
#  'BRTS': set(['BRTS Route', 'BRTS Station']),
#  'Balol': set(['Balol Nagar Road']),
#  'BalolNagar': set(['BalolNagar Cross Road']),
#  'Balvantrai': set(['Balvantrai Mehta Road']),
#  'Bapuangar': set(['Bapuangar']),
#  'Bapunagar': set(['Bapunagar']),
#  'Behind': set(['Behind Ayodhyanagar']),
#  'Bhadaj': set(['Bhadaj Cross Road,']),
#  'Bhagwat': set(['Bhagwat Nagar Society']),
#  'Bopal': set(['Bopal - Sanand Bypass Road']),
#  'C.G.': set(['C.G. Road']),
#  'CG': set(['CG Road']),
#  'CH': set(['CH Road']),
#  'CHANAKYAPURI': set(['CHANAKYAPURI ROAD']),
#  'CHANDLODIA': set(['CHANDLODIA STATION ROAD']),
#  'Chimanlal': set(['Chimanlal Girdharlal Road']),
#  'Commerce': set(['Commerce College Road']),
#  'Corporate': set(['Corporate Road']),
#  'D12,': set(['D12, Asmaakam, Makrba road, Vejalpur']),
#  'Dada': set(['Dada Bhagwan Trimandir, Ahmedabad - Kalol Highway, Adalaj, Gandhinagar, Gujarat, India ']),
#  'Danapith': set(['Danapith Road']),
#  'Dmart': set(['Dmart road / nikol naroda road']),
#  'Dr.': set(['Dr. Ambedkar Road',
#              'Dr. Hariprasad Desai Marg',
#              'Dr. Jivraj Mehta Road',
#              'Dr. Vikram Sarabhai Road']),
#  'Drive-in': set(['Drive-in Road']),
#  'Dutt': set(['Dutt Socity, Bhattha, Paldi', 'Dutt society, Bhattha']),
#  'Ellisbridge': set(['Ellisbridge']),
#  'FACTORY': set(['FACTORY Road no.14']),
#  'GST': set(['GST Crossing',
#              'GST Crossing Road, New Ranip',
#              'GST Crossing Road, Ranip',
#              'GST Crossing, New Ranip',
#              'GST Road']),
#  'GVMM': set(['GVMM']),
#  'Gala': set(['Gala Gym Khana Road']),
#  'Gandhinagar-Ahmedabad': set(['Gandhinagar-Ahmedabad Highway']),
#  'Ghatlodia': set(['Ghatlodia']),
#  'Gidc': set(['Gidc 1 road']),
#  'Girdharnagar': set(['Girdharnagar Road']),
#  'Gota': set(['Gota Road', 'Gota Road NH-147']),
#  'Gujarat': set(['Gujarat', 'Gujarat University Internal Road']),
#  'Gulbai': set(['Gulbai Tekra Road']),
#  'Gurukul': set(['Gurukul Road, Vishram Marg']),
#  'Hebatpur': set(['Hebatpur Road', 'Hebatpur road']),
#  'Heena': set(['Heena Park Sosciety, Settellte']),
#  'Hirawadi': set(['Hirawadi', 'Hirawadi road']),
#  'Indira': set(['Indira Bridge Circle . Apollo Complex']),
#  'Indroda': set(['Indroda Circle']),
#  'JUNA': set(['JUNA MADHUPURA ROAD']),
#  'Jamalpur': set(['Jamalpur Road']),
#  'Jawaharlal': set(['Jawaharlal Nehru Road']),
#  'Judges': set(['Judges Bungalow Road', 'Judges Bunglow Road']),
#  'Kasturba': set(['Kasturba Gandhi Road']),
#  'Kendriya': set(['Kendriya Vihar Society']),
#  'Kh': set(['Kh road']),
#  'Kh-0': set(['Kh-0']),
#  'Khanpur': set(['Khanpur']),
#  'Khokhra': set(['Khokhra Road']),
#  'Kotar': set(['Kotar pur-airport road']),
#  'Krupa': set(['Krupa Shankar Joshi Marg']),
#  'LD': set(['LD College of Engineering Internal Road']),
#  'Lakhudi': set(['Lakhudi Circle']),
#  'Lala': set(['Lala Lajpat Rai Marg']),
#  'Law': set(['Law Garden Road']),
#  'Main': set(['Main bazar road road']),
#  'Mandir': set(['Mandir orad']),
#  'Manek': set(['Manek Baug Road']),
#  'Maninagar': set(['Maninagar']),
#  'N.': set(['N. Palm Ave. #210']),
#  'NEW': set(['NEW ROAD NIRNAYNAGAR']),
#  'NH8': set(['NH8']),
#  'NH8A': set(['NH8A']),
#  'NH8C': set(['NH8C']),
#  'Narmada': set(['Narmada Residency road']),
#  'Naroda': set(['Naroda Road']),
#  'Narol': set(['Narol Sarkhej Road']),
#  'Nav-Sarjan': set(['Nav-Sarjan School Road']),
#  'Nav-sarjan': set(['Nav-sarjan School Road']),
#  'Nava': set(['Nava Naroda Road']),
#  'Navrang': set(['Navrang Society']),
#  'Near': set(['Near Balolnagar Cross Road',
#               'Near Krishnabaug Cross Roads, Maninagar',
#               'Near NH 147',
#               'Near Vyasvadi']),
#  'Nehru': set(['Nehru Bridge']),
#  'Nehrunagar': set(['Nehrunagar']),
#  'Netaji': set(['Netaji Subhash Chandra Road']),
#  'New': set(['New Nirnaynaga Road']),
#  'Nikol-Naroda': set(['Nikol-Naroda Road']),
#  'Nirant': set(['Nirant Building, Simandhar City']),
#  'Nirnaynagar': set(['Nirnaynagar road']),
#  'North': set(['North Bopal']),
#  'Nr.': set(['Nr. Chandan Party Plot']),
#  'Odhav': set(['Odhav Road']),
#  'Opposite': set(['Opposite Sidi Saiyad Jali']),
#  'Paldi': set(['Paldi']),
#  'Panchvati': set(['Panchvati Crossroads']),
#  'Panjarapole': set(['Panjarapole Cross Roads']),
#  'Pragatinagar': set(['Pragatinagar']),
#  'Prasang': set(['Prasang Party Plot Rd, Chanakyapuri']),
#  'Purshottam': set(['Purshottam Malvankar Marg']),
#  'Rabari': set(['Rabari colony road']),
#  'Rakhial': set(['Rakhial Road']),
#  'Rambaug,': set(['Rambaug, Near Karnavati Club Road']),
#  'Ramdevnagar': set(['Ramdevnagar road']),
#  'Ranip': set(['Ranip']),
#  'Relief': set(['Relief Road']),
#  'Ring': set(['Ring Road']),
#  'S': set(['S G Highway', 'S P Ring Road']),
#  'S.G.': set(['S.G. Highway']),
#  'SH-41': set(['SH-41']),
#  'SHIVAM': set(['SHIVAM  SQUAR']),
#  'SM': set(['SM Road']),
#  'SPEC': set(['SPEC House, Parth Complex, Navrangpura, Nr. Swastik Cross Roads']),
#  'Sabarmati': set(['Sabarmati Riverfront Walkway, Usmanpura']),
#  'Samartheshwar': set(['Samartheshwar Mahadev Road']),
#  'Sardar': set(['Sardar Patel Ring Road']),
#  'Sargam': set(['Sargam Marg']),
#  'Sargasan': set(['Sargasan Cross Road', 'Sargasan cross road']),
#  'Satellite': set(['Satellite Road']),
#  'Satya': set(['Satya Marg']),
#  'Satyamev': set(['Satyamev Vista Road']),
#  'Sector': set(['Sector 1']),
#  'Serenade': set(['Serenade Farm, Survey no. 121, Sughad, Near Koba circle']),
#  'Service': set(['Service road - Sarkhej Gandhinagar Highway']),
#  'Shantigram': set(['Shantigram']),
#  'Shree': set(['Shree Bapalal Dandwala Marg']),
#  'Shreenath': set(['Shreenath Nagar society']),
#  'Shri': set(['Shri Khandubhai Desai Marg']),
#  'Shyam': set(['Shyam Sunder Row House, Behind Manav Mandir']),
#  'Sindhu': set(['Sindhu Bhavan Road',
#                 'Sindhu Bhawan Road',
#                 'Sindhu bhawan road']),
#  'Sindhubhavan': set(['Sindhubhavan Road']),
#  'Sola': set(['Sola Road']),
#  'St.': set(["St. Xavier's College Road"]),
#  'Stadium': set(['Stadium Circle', 'Stadium Commerce Six Roads']),
#  'Station': set(['Station Road']),
#  'Sukharam': set(['Sukharam Nagar Road']),
#  'Sundarvan,': set(['Sundarvan, Satellite Road']),
#  'Surendra': set(['Surendra Mangaldas Road']),
#  'Swami': set(['Swami Bapa Smruti Mandir Road', 'Swami Vivekananda Road']),
#  'Swastik': set(['Swastik Cross Road', 'Swastik Society Road']),
#  'Thaltej': set(['Thaltej Road', 'Thaltej Underbridge']),
#  'Tirupati': set(['Tirupati Road']),
#  'University': set(['University Road']),
#  'Uttamnagar,': set(['Uttamnagar, Ahmedabad', 'Uttamnagar, Maninagar']),
#  'Vatva': set(['Vatva GIDC road',
#                'Vatva phase -2 road',
#                'Vatva railway station road']),
#  'Vatva-1': set(['Vatva-1 Road']),
#  'Vatwa': set(['Vatwa Road']),
#  'Vijay': set(['Vijay Cross Roads']),
#  'Vijubhai': set(['Vijubhai Dave Marg']),
#  'Vrajraiji': set(['Vrajraiji Colony']),
#  'ashram': set(['ashram road']),
#  'bunglow': set(['bunglow area']),
#  'gandhi': set(['gandhi  bridge']),
#  'kankariya': set(['kankariya gate no.3']),
#  'kathwada': set(['kathwada GiDc road']),
#  'kh': set(['kh road']),
#  'mauraya': set(['mauraya gidc maha gujrat gidc road']),
#  'paldi': set(['paldi gam road']),
#  'ramdev': set(['ramdev nagar road']),
#  'sargasan,': set(['sargasan, kh road']),
#  'sbk': set(['sbk society']),
#  'shahpur': set(['shahpur']),
#  'shiv-sankalp': set(['shiv-sankalp soc. amikunj cross road']),
#  'shreyas': set(['shreyas flyover service road']),
#  'sidhubahavan': set(['sidhubahavan road']),
#  'tajpur': set(['tajpur road']),
#  'tanman': set(['tanman chokdi']),
#  'vijay': set(['vijay char rasta', 'vijay cross road'])}
# GVMM => GVMM
# Service road - Sarkhej Gandhinagar Highway => Service Road - Sarkhej Gandhinagar Highway
# Danapith Road => Danapith Road
# 132 Ft. Ring Road => 132 Feet Ring Road
# Netaji Subhash Chandra Road => Netaji Subhash Chandra Road
# Kh-0 => Kh-0
# Nehrunagar => Nehrunagar
# Khokhra Road => Khokhra Road
# Odhav Road => Odhav Road
# SH-41 => SH-41
# GST Crossing Road, Ranip => GST Crossing Road, Ranip
# GST Crossing => GST Crossing
# GST Road => GST Road
# GST Crossing Road, New Ranip => GST Crossing Road, New Ranip
# GST Crossing, New Ranip => GST Crossing, New Ranip
# Swastik Cross Road => Swastik Cross Road
# Swastik Society Road => Swastik Society Road
# Nav-sarjan School Road => Nav-Sarjan School Road
# Ellisbridge => Ellisbridge
# Vrajraiji Colony => Vrajraiji Colony
# Manek Baug Road => Manek Baug Road
# Gandhinagar-Ahmedabad Highway => Gandhinagar-Ahmedabad Highway
# 8 aasiyana society jivrajpark nr 132 ring road ahmedabad => 8 Aasiyana Society Jivrajpark Nr 132 Ring Road Ahmedabad
# kankariya gate no.3 => Kankariya Gate No.3
# Prasang Party Plot Rd, Chanakyapuri => Prasang Party Plot Rd, Chanakyapuri
# Serenade Farm, Survey no. 121, Sughad, Near Koba circle => Serenade Farm, Survey No. 121, Sughad, Near Koba Circle
# Sardar Patel Ring Road => Sardar Patel Ring Road
# 120 Feet Ring Road => 120 Feet Ring Road
# tanman chokdi => Tanman Chokdi
# Gidc 1 road => Gidc 1 Road
# Krupa Shankar Joshi Marg => Krupa Shankar Joshi Marg
# shiv-sankalp soc. amikunj cross road => Shiv-Sankalp Society Amikunj Cross Road
# Panchvati Crossroads => Panchvati Crossroads
# sargasan, kh road => Sargasan, Kh Road
# bunglow area => Bunglow Area
# paldi gam road => Paldi Gam Road
# Nirant Building, Simandhar City => Nirant Building, Simandhar City
# D12, Asmaakam, Makrba road, Vejalpur => D12, Asmaakam, Makrba Road, Vejalpur
# S.G. Highway => S.G. Highway
# BRTS Route => BRTS Route
# BRTS Station => BRTS Station
# Jawaharlal Nehru Road => Jawaharlal Nehru Road
# Shantigram => Shantigram
# Station Road => Station Road
# gandhi  bridge => Gandhi  Bridge
# Vatva-1 Road => Vatva-1 Road
# Ring Road => Ring Road
# Bapunagar => Bapunagar
# SPEC House, Parth Complex, Navrangpura, Nr. Swastik Cross Roads => SPEC House, Parth Complex, Navrangpura, NR Swastik Cross Road
# Naroda Road => Naroda Road
# ramdev nagar road => Ramdev Nagar Road
# ashram road => Ashram Road
# CHANAKYAPURI ROAD => CHANAKYAPURI ROAD
# CHANDLODIA STATION ROAD => CHANDLODIA STATION ROAD
# Nirnaynagar road => Nirnaynagar Road
# Gurukul Road, Vishram Marg => Gurukul Road, Vishram Marg
# Dr. Jivraj Mehta Road => Dr. Jivraj Mehta Road
# Dr. Hariprasad Desai Marg => Dr. Hariprasad Desai Marg
# Dr. Ambedkar Road => Dr. Ambedkar Road
# Dr. Vikram Sarabhai Road => Dr. Vikram Sarabhai Road
# New Nirnaynaga Road => New Nirnaynaga Road
# Akshar Avenue => Akshar Avenue
# Ramdevnagar road => Ramdevnagar Road
# 101, Paritosh Building, Usmanpura, Ashram Road => 101, Paritosh Building, Usmanpura, Ashram Road
# Satellite Road => Satellite Road
# Narol Sarkhej Road => Narol Sarkhej Road
# Surendra Mangaldas Road => Surendra Mangaldas Road
# shahpur => Shahpur
# Shreenath Nagar society => Shreenath Nagar Society
# Hirawadi road => Hirawadi Road
# Hirawadi => Hirawadi
# Sindhu bhawan road => Sindhu Bhawan Road
# Sindhu Bhawan Road => Sindhu Bhawan Road
# Sindhu Bhavan Road => Sindhu Bhavan Road
# Commerce College Road => Commerce College Road
# Lakhudi Circle => Lakhudi Circle
# Sargasan cross road => Sargasan Cross Road
# Sargasan Cross Road => Sargasan Cross Road
# Sargam Marg => Sargam Marg
# University Road => University Road
# Near NH 147 => Near NH 147
# Near Vyasvadi => Near Vyasvadi
# Near Balolnagar Cross Road => Near Balolnagar Cross Road
# Near Krishnabaug Cross Roads, Maninagar => Near Krishnabaug Cross Roads, Maninagar
# sidhubahavan road => Sidhubahavan Road
# Satya Marg => Satya Marg
# sbk society => SBK Society
# 100 Ft. Road => 100 Feet Road
# 100 ft Road => 100 Feet Road
# Heena Park Sosciety, Settellte => Heena Park Sosciety, Settellte
# Purshottam Malvankar Marg => Purshottam Malvankar Marg
# Nava Naroda Road => Nava Naroda Road
# Vijubhai Dave Marg => Vijubhai Dave Marg
# Ashram Road => Ashram Road
# mauraya gidc maha gujrat gidc road => Mauraya Gidc Maha Gujrat Gidc Road
# Shree Bapalal Dandwala Marg => Shree Bapalal Dandwala Marg
# Chimanlal Girdharlal Road => Chimanlal Girdharlal Road
# Gala Gym Khana Road => Gala Gym Khana Road
# Satyamev Vista Road => Satyamev Vista Road
# shreyas flyover service road => Shreyas Flyover Service Road
# Bapuangar => Bapuangar
# Mandir orad => Mandir Orad
# vijay char rasta => Vijay Char Road
# vijay cross road => Vijay Cross Road
# ACHER ROAD => ACHER ROAD
# Kasturba Gandhi Road => Kasturba Gandhi Road
# Drive-in Road => Drive-In Road
# kathwada GiDc road => Kathwada Gidc Road
# Nehru Bridge => Nehru Bridge
# St. Xavier's College Road => St. Xavier'S College Road
# Balol Nagar Road => Balol Nagar Road
# 2nd Floor, Aditya Complex, Opp kasturi Dining Hall, Paldi Cross Road, Paldi => 2Nd Floor, Aditya Complex, Opp Kasturi Dining Hall, Paldi Cross Road, Paldi
# 2nd Floor, Dev Arc Mall, Satellite Rd, Off S.G Highway, Near Iskcon Bridge => 2Nd Floor, Dev Arc Mall, Satellite Rd, Off S.G Highway, Near Iskcon Bridge
# Behind Ayodhyanagar => Behind Ayodhyanagar
# Shyam Sunder Row House, Behind Manav Mandir => Shyam Sunder Row House, Behind Manav Mandir
# Stadium Circle => Stadium Circle
# Stadium Commerce Six Roads => Stadium Commerce Six Road
# SM Road => SM Road
# CG Road => CG Road
# NEW ROAD NIRNAYNAGAR => NEW ROAD NIRNAYNAGAR
# S P Ring Road => S P Ring Road
# S G Highway => S G Highway
# B/H AryaVilla => B/H Aryavilla
# North Bopal => North Bopal
# Kotar pur-airport road => Kotar Pur-Airport Road
# Ranip => Ranip
# Opposite Sidi Saiyad Jali => Opposite Sidi Saiyad Jali
# Corporate Road => Corporate Road
# Gota Road => Gota Road
# Gota Road NH-147 => Gota Road NH-147
# Sola Road => Sola Road
# Thaltej Road => Thaltej Road
# Thaltej Underbridge => Thaltej Underbridge
# Bhagwat Nagar Society => Bhagwat Nagar Society
# Samartheshwar Mahadev Road => Samartheshwar Mahadev Road
# Sukharam Nagar Road => Sukharam Nagar Road
# Narmada Residency road => Narmada Residency Road
# CH Road => CH Road
# N. Palm Ave. #210 => N. Palm Avenue #210
# Paldi => Paldi
# Rambaug, Near Karnavati Club Road => Rambaug, Near Karnavati Club Road
# Kh road => Kh Road
# Sundarvan, Satellite Road => Sundarvan, Satellite Road
# FACTORY Road no.14 => FACTORY Road No.14
# SHIVAM  SQUAR => SHIVAM  SQUAR
# Sabarmati Riverfront Walkway, Usmanpura => Sabarmati Riverfront Walkway, Usmanpura
# Relief Road => Relief Road
# Pragatinagar => Pragatinagar
# Indroda Circle => Indroda Circle
# Khanpur => Khanpur
# Akhabarnagar Circle => Akhabarnagar Circle
# NH8C => NH8C
# NH8A => NH8A
# Sector 1 => Sector 1
# BalolNagar Cross Road => Balolnagar Cross Road
# Nr. Chandan Party Plot => NR Chandan Party Plot
# Jamalpur Road => Jamalpur Road
# Dutt society, Bhattha => Dutt Society, Bhattha
# Dutt Socity, Bhattha, Paldi => Dutt Socity, Bhattha, Paldi
# Shri Khandubhai Desai Marg => Shri Khandubhai Desai Marg
# Gulbai Tekra Road => Gulbai Tekra Road
# Nikol-Naroda Road => Nikol-Naroda Road
# Judges Bunglow Road => Judges Bunglow Road
# Judges Bungalow Road => Judges Bungalow Road
# Rabari colony road => Rabari Colony Road
# Navrang Society => Navrang Society
# Vatva phase -2 road => Vatva Phase -2 Road
# Vatva GIDC road => Vatva GIDC Road
# Vatva railway station road => Vatva Railway Station Road
# JUNA MADHUPURA ROAD => JUNA MADHUPURA ROAD
# Indira Bridge Circle . Apollo Complex => Indira Bridge Circle . Apollo Complex
# Uttamnagar, Ahmedabad => Uttamnagar, Ahmedabad
# Uttamnagar, Maninagar => Uttamnagar, Maninagar
# Asmita Society => Asmita Society
# Main bazar road road => Main Bazar Road Road
# Adalaj -sarkhej road => Adalaj -Sarkhej Road
# LD College of Engineering Internal Road => LD College Of Engineering Internal Road
# Kendriya Vihar Society => Kendriya Vihar Society
# Maninagar => Maninagar
# Tirupati Road => Tirupati Road
# Bopal - Sanand Bypass Road => Bopal - Sanand Bypass Road
# Hebatpur road => Hebatpur Road
# Hebatpur Road => Hebatpur Road
# Balvantrai Mehta Road => Balvantrai Mehta Road
# Sindhubhavan Road => Sindhubhavan Road
# Law Garden Road => Law Garden Road
# Anand nagar road => Anand Nagar Road
# Vatwa Road => Vatwa Road
# Bhadaj Cross Road, => Bhadaj Cross Road,
# Swami Vivekananda Road => Swami Vivekananda Road
# Swami Bapa Smruti Mandir Road => Swami Bapa Smruti Mandir Road
# Dada Bhagwan Trimandir, Ahmedabad - Kalol Highway, Adalaj, Gandhinagar, Gujarat, India  => Dada Bhagwan Trimandir, Ahmedabad - Kalol Highway, Adalaj, Gandhinagar, Gujarat, India
# Girdharnagar Road => Girdharnagar Road
# Lala Lajpat Rai Marg => Lala Lajpat Rai Marg
# Rakhial Road => Rakhial Road
# Airport Road => Airport Road
# Panjarapole Cross Roads => Panjarapole Cross Road
# Gujarat University Internal Road => Gujarat University Internal Road
# Gujarat => Gujarat
# Vijay Cross Roads => Vijay Cross Road
# NH8 => NH8
# Ghatlodia => Ghatlodia
# ASarwa => Asarwa
# C.G. Road => C.G. Road
# kh road => Kh Road
# Ahmedabad-Kalol Highway => Ahmedabad-Kalol Highway
# Dmart road / nikol naroda road => Dmart Road / Nikol Naroda Road
# tajpur road => Tajpur Road
# Nav-Sarjan School Road => Nav-Sarjan School Road

# %%
filename = open("ahmedabad.osm", "r")

mapping = {"ahmedabad": "Ahmedabad",
           "Ahmadabad": "Ahmedabad",
           "Ahamadabad": "Ahmedabad",
           "Nr.": "NR",
           "Ave.": "Avenue",
           "sbk": "SBK",
           "gandhi": "Gandhi",
           "bridge": "Bridge",
           "road": "Road",
           "Ft.": "Feet",
           "ft": "Feet",
           "Rd": "Road",
           "Rd.": "Road",
           "rasta": "Road",
           "Roads": "Road",
           "society": "Society",
           "soc.": "Society",
           "Socity": "Society",
           "Gujarat.": "Gujarat,"
            }

# %%
mapping2 =  {"E"  : "East",
             "E." : "East",
             "N"  : "North",
             "N." : "North",
             "S"  : "South",
             "S." : "South",
             "W"  : "West",
             "W." : "West"}

# %%
'''
The update name function implements the change. If a street name has the defined string which is defined in the two mapping
dictionaries, then the change is made as defined.
'''


def update_name(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)
    
    return name

# %%
# Search string for the regex. If it is matched and not in the expected list then add this as a key to the set.
def audit_street(street_types, street_name): 
    m = regex.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem): # Check if it is a street name
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile): # return the list that satify the above two functions
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street(street_types, tag.attrib['v'])
                    

    return street_types

pprint.pprint(dict(audit(OSMFILE_sample))) # print the existing names
# Out:
# {'100': set(['100 Ft. Road', '100 ft Road']),
#  '101,': set(['101, Paritosh Building, Usmanpura, Ashram Road']),
#  '120': set(['120 Feet Ring Road']),
#  '132': set(['132 Ft. Ring Road']),
#  '2nd': set(['2nd Floor, Aditya Complex, Opp kasturi Dining Hall, Paldi Cross Road, Paldi',
#              '2nd Floor, Dev Arc Mall, Satellite Rd, Off S.G Highway, Near Iskcon Bridge']),
#  '8': set(['8 aasiyana society jivrajpark nr 132 ring road ahmedabad']),
#  'ACHER': set(['ACHER ROAD']),
#  'ASarwa': set(['ASarwa']),
#  'Adalaj': set(['Adalaj -sarkhej road']),
#  'Ahmedabad-Kalol': set(['Ahmedabad-Kalol Highway']),
#  'Airport': set(['Airport Road']),
#  'Akhabarnagar': set(['Akhabarnagar Circle']),
#  'Akshar': set(['Akshar Avenue']),
#  'Anand': set(['Anand nagar road']),
#  'Ashram': set(['Ashram Road']),
#  'Asmita': set(['Asmita Society']),
#  'B/H': set(['B/H AryaVilla']),
#  'BRTS': set(['BRTS Route', 'BRTS Station']),
#  'Balol': set(['Balol Nagar Road']),
#  'BalolNagar': set(['BalolNagar Cross Road']),
#  'Balvantrai': set(['Balvantrai Mehta Road']),
#  'Bapuangar': set(['Bapuangar']),
#  'Bapunagar': set(['Bapunagar']),
#  'Behind': set(['Behind Ayodhyanagar']),
#  'Bhadaj': set(['Bhadaj Cross Road,']),
#  'Bhagwat': set(['Bhagwat Nagar Society']),
#  'Bopal': set(['Bopal - Sanand Bypass Road']),
#  'C.G.': set(['C.G. Road']),
#  'CG': set(['CG Road']),
#  'CH': set(['CH Road']),
#  'CHANAKYAPURI': set(['CHANAKYAPURI ROAD']),
#  'CHANDLODIA': set(['CHANDLODIA STATION ROAD']),
#  'Chimanlal': set(['Chimanlal Girdharlal Road']),
#  'Commerce': set(['Commerce College Road']),
#  'Corporate': set(['Corporate Road']),
#  'D12,': set(['D12, Asmaakam, Makrba road, Vejalpur']),
#  'Dada': set(['Dada Bhagwan Trimandir, Ahmedabad - Kalol Highway, Adalaj, Gandhinagar, Gujarat, India ']),
#  'Danapith': set(['Danapith Road']),
#  'Dmart': set(['Dmart road / nikol naroda road']),
#  'Dr.': set(['Dr. Ambedkar Road',
#              'Dr. Hariprasad Desai Marg',
#              'Dr. Jivraj Mehta Road',
#              'Dr. Vikram Sarabhai Road']),
#  'Drive-in': set(['Drive-in Road']),
#  'Dutt': set(['Dutt Socity, Bhattha, Paldi', 'Dutt society, Bhattha']),
#  'Ellisbridge': set(['Ellisbridge']),
#  'FACTORY': set(['FACTORY Road no.14']),
#  'GST': set(['GST Crossing',
#              'GST Crossing Road, New Ranip',
#              'GST Crossing Road, Ranip',
#              'GST Crossing, New Ranip',
#              'GST Road']),
#  'GVMM': set(['GVMM']),
#  'Gala': set(['Gala Gym Khana Road']),
#  'Gandhinagar-Ahmedabad': set(['Gandhinagar-Ahmedabad Highway']),
#  'Ghatlodia': set(['Ghatlodia']),
#  'Gidc': set(['Gidc 1 road']),
#  'Girdharnagar': set(['Girdharnagar Road']),
#  'Gota': set(['Gota Road', 'Gota Road NH-147']),
#  'Gujarat': set(['Gujarat', 'Gujarat University Internal Road']),
#  'Gulbai': set(['Gulbai Tekra Road']),
#  'Gurukul': set(['Gurukul Road, Vishram Marg']),
#  'Hebatpur': set(['Hebatpur Road', 'Hebatpur road']),
#  'Heena': set(['Heena Park Sosciety, Settellte']),
#  'Hirawadi': set(['Hirawadi', 'Hirawadi road']),
#  'Indira': set(['Indira Bridge Circle . Apollo Complex']),
#  'Indroda': set(['Indroda Circle']),
#  'JUNA': set(['JUNA MADHUPURA ROAD']),
#  'Jamalpur': set(['Jamalpur Road']),
#  'Jawaharlal': set(['Jawaharlal Nehru Road']),
#  'Judges': set(['Judges Bungalow Road', 'Judges Bunglow Road']),
#  'Kasturba': set(['Kasturba Gandhi Road']),
#  'Kendriya': set(['Kendriya Vihar Society']),
#  'Kh': set(['Kh road']),
#  'Kh-0': set(['Kh-0']),
#  'Khanpur': set(['Khanpur']),
#  'Khokhra': set(['Khokhra Road']),
#  'Kotar': set(['Kotar pur-airport road']),
#  'Krupa': set(['Krupa Shankar Joshi Marg']),
#  'LD': set(['LD College of Engineering Internal Road']),
#  'Lakhudi': set(['Lakhudi Circle']),
#  'Lala': set(['Lala Lajpat Rai Marg']),
#  'Law': set(['Law Garden Road']),
#  'Main': set(['Main bazar road road']),
#  'Mandir': set(['Mandir orad']),
#  'Manek': set(['Manek Baug Road']),
#  'Maninagar': set(['Maninagar']),
#  'N.': set(['N. Palm Ave. #210']),
#  'NEW': set(['NEW ROAD NIRNAYNAGAR']),
#  'NH8': set(['NH8']),
#  'NH8A': set(['NH8A']),
#  'NH8C': set(['NH8C']),
#  'Narmada': set(['Narmada Residency road']),
#  'Naroda': set(['Naroda Road']),
#  'Narol': set(['Narol Sarkhej Road']),
#  'Nav-Sarjan': set(['Nav-Sarjan School Road']),
#  'Nav-sarjan': set(['Nav-sarjan School Road']),
#  'Nava': set(['Nava Naroda Road']),
#  'Navrang': set(['Navrang Society']),
#  'Near': set(['Near Balolnagar Cross Road',
#               'Near Krishnabaug Cross Roads, Maninagar',
#               'Near NH 147',
#               'Near Vyasvadi']),
#  'Nehru': set(['Nehru Bridge']),
#  'Nehrunagar': set(['Nehrunagar']),
#  'Netaji': set(['Netaji Subhash Chandra Road']),
#  'New': set(['New Nirnaynaga Road']),
#  'Nikol-Naroda': set(['Nikol-Naroda Road']),
#  'Nirant': set(['Nirant Building, Simandhar City']),
#  'Nirnaynagar': set(['Nirnaynagar road']),
#  'North': set(['North Bopal']),
#  'Nr.': set(['Nr. Chandan Party Plot']),
#  'Odhav': set(['Odhav Road']),
#  'Opposite': set(['Opposite Sidi Saiyad Jali']),
#  'Paldi': set(['Paldi']),
#  'Panchvati': set(['Panchvati Crossroads']),
#  'Panjarapole': set(['Panjarapole Cross Roads']),
#  'Pragatinagar': set(['Pragatinagar']),
#  'Prasang': set(['Prasang Party Plot Rd, Chanakyapuri']),
#  'Purshottam': set(['Purshottam Malvankar Marg']),
#  'Rabari': set(['Rabari colony road']),
#  'Rakhial': set(['Rakhial Road']),
#  'Rambaug,': set(['Rambaug, Near Karnavati Club Road']),
#  'Ramdevnagar': set(['Ramdevnagar road']),
#  'Ranip': set(['Ranip']),
#  'Relief': set(['Relief Road']),
#  'Ring': set(['Ring Road']),
#  'S': set(['S G Highway', 'S P Ring Road']),
#  'S.G.': set(['S.G. Highway']),
#  'SH-41': set(['SH-41']),
#  'SHIVAM': set(['SHIVAM  SQUAR']),
#  'SM': set(['SM Road']),
#  'SPEC': set(['SPEC House, Parth Complex, Navrangpura, Nr. Swastik Cross Roads']),
#  'Sabarmati': set(['Sabarmati Riverfront Walkway, Usmanpura']),
#  'Samartheshwar': set(['Samartheshwar Mahadev Road']),
#  'Sardar': set(['Sardar Patel Ring Road']),
#  'Sargam': set(['Sargam Marg']),
#  'Sargasan': set(['Sargasan Cross Road', 'Sargasan cross road']),
#  'Satellite': set(['Satellite Road']),
#  'Satya': set(['Satya Marg']),
#  'Satyamev': set(['Satyamev Vista Road']),
#  'Sector': set(['Sector 1']),
#  'Serenade': set(['Serenade Farm, Survey no. 121, Sughad, Near Koba circle']),
#  'Service': set(['Service road - Sarkhej Gandhinagar Highway']),
#  'Shantigram': set(['Shantigram']),
#  'Shree': set(['Shree Bapalal Dandwala Marg']),
#  'Shreenath': set(['Shreenath Nagar society']),
#  'Shri': set(['Shri Khandubhai Desai Marg']),
#  'Shyam': set(['Shyam Sunder Row House, Behind Manav Mandir']),
#  'Sindhu': set(['Sindhu Bhavan Road',
#                 'Sindhu Bhawan Road',
#                 'Sindhu bhawan road']),
#  'Sindhubhavan': set(['Sindhubhavan Road']),
#  'Sola': set(['Sola Road']),
#  'St.': set(["St. Xavier's College Road"]),
#  'Stadium': set(['Stadium Circle', 'Stadium Commerce Six Roads']),
#  'Station': set(['Station Road']),
#  'Sukharam': set(['Sukharam Nagar Road']),
#  'Sundarvan,': set(['Sundarvan, Satellite Road']),
#  'Surendra': set(['Surendra Mangaldas Road']),
#  'Swami': set(['Swami Bapa Smruti Mandir Road', 'Swami Vivekananda Road']),
#  'Swastik': set(['Swastik Cross Road', 'Swastik Society Road']),
#  'Thaltej': set(['Thaltej Road', 'Thaltej Underbridge']),
#  'Tirupati': set(['Tirupati Road']),
#  'University': set(['University Road']),
#  'Uttamnagar,': set(['Uttamnagar, Ahmedabad', 'Uttamnagar, Maninagar']),
#  'Vatva': set(['Vatva GIDC road',
#                'Vatva phase -2 road',
#                'Vatva railway station road']),
#  'Vatva-1': set(['Vatva-1 Road']),
#  'Vatwa': set(['Vatwa Road']),
#  'Vijay': set(['Vijay Cross Roads']),
#  'Vijubhai': set(['Vijubhai Dave Marg']),
#  'Vrajraiji': set(['Vrajraiji Colony']),
#  'ashram': set(['ashram road']),
#  'bunglow': set(['bunglow area']),
#  'gandhi': set(['gandhi  bridge']),
#  'kankariya': set(['kankariya gate no.3']),
#  'kathwada': set(['kathwada GiDc road']),
#  'kh': set(['kh road']),
#  'mauraya': set(['mauraya gidc maha gujrat gidc road']),
#  'paldi': set(['paldi gam road']),
#  'ramdev': set(['ramdev nagar road']),
#  'sargasan,': set(['sargasan, kh road']),
#  'sbk': set(['sbk society']),
#  'shahpur': set(['shahpur']),
#  'shiv-sankalp': set(['shiv-sankalp soc. amikunj cross road']),
#  'shreyas': set(['shreyas flyover service road']),
#  'sidhubahavan': set(['sidhubahavan road']),
#  'tajpur': set(['tajpur road']),
#  'tanman': set(['tanman chokdi']),
#  'vijay': set(['vijay char rasta', 'vijay cross road'])}

# %%
street_type_re  = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_type_pre = re.compile(r'^[NSEW]\b\.?', re.IGNORECASE)

# %%
def string_case(s): # change string into titleCase except for UpperCase
    if s.isupper():
        return s
    else:
        return s.title()

# %%
# return the updated names
def update_name(name, mapping):
    name = name.split(' ')
    for i in range(len(name)):
        if name[i] in mapping:
            name[i] = mapping[name[i]]
            name[i] = string_case(name[i])
        else:
            name[i] = string_case(name[i])
    
    name = ' '.join(name)
   

    return name

update_street = audit(OSMFILE_sample)

# %%
# print the updated names
for street_type, ways in update_street.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# GVMM => GVMM
# Service road - Sarkhej Gandhinagar Highway => Service Road - Sarkhej Gandhinagar Highway
# Danapith Road => Danapith Road
# 132 Ft. Ring Road => 132 Feet Ring Road
# Netaji Subhash Chandra Road => Netaji Subhash Chandra Road
# Kh-0 => Kh-0
# Nehrunagar => Nehrunagar
# Khokhra Road => Khokhra Road
# Odhav Road => Odhav Road
# SH-41 => SH-41
# GST Crossing Road, Ranip => GST Crossing Road, Ranip
# GST Crossing => GST Crossing
# GST Road => GST Road
# GST Crossing Road, New Ranip => GST Crossing Road, New Ranip
# GST Crossing, New Ranip => GST Crossing, New Ranip
# Swastik Cross Road => Swastik Cross Road
# Swastik Society Road => Swastik Society Road
# Nav-sarjan School Road => Nav-Sarjan School Road
# Ellisbridge => Ellisbridge
# Vrajraiji Colony => Vrajraiji Colony
# Manek Baug Road => Manek Baug Road
# Gandhinagar-Ahmedabad Highway => Gandhinagar-Ahmedabad Highway
# 8 aasiyana society jivrajpark nr 132 ring road ahmedabad => 8 Aasiyana Society Jivrajpark Nr 132 Ring Road Ahmedabad
# kankariya gate no.3 => Kankariya Gate No.3
# Prasang Party Plot Rd, Chanakyapuri => Prasang Party Plot Rd, Chanakyapuri
# Serenade Farm, Survey no. 121, Sughad, Near Koba circle => Serenade Farm, Survey No. 121, Sughad, Near Koba Circle
# Sardar Patel Ring Road => Sardar Patel Ring Road
# 120 Feet Ring Road => 120 Feet Ring Road
# tanman chokdi => Tanman Chokdi
# Gidc 1 road => Gidc 1 Road
# Krupa Shankar Joshi Marg => Krupa Shankar Joshi Marg
# shiv-sankalp soc. amikunj cross road => Shiv-Sankalp Society Amikunj Cross Road
# Panchvati Crossroads => Panchvati Crossroads
# sargasan, kh road => Sargasan, Kh Road
# bunglow area => Bunglow Area
# paldi gam road => Paldi Gam Road
# Nirant Building, Simandhar City => Nirant Building, Simandhar City
# D12, Asmaakam, Makrba road, Vejalpur => D12, Asmaakam, Makrba Road, Vejalpur
# S.G. Highway => S.G. Highway
# BRTS Route => BRTS Route
# BRTS Station => BRTS Station
# Jawaharlal Nehru Road => Jawaharlal Nehru Road
# Shantigram => Shantigram
# Station Road => Station Road
# gandhi  bridge => Gandhi  Bridge
# Vatva-1 Road => Vatva-1 Road
# Ring Road => Ring Road
# Bapunagar => Bapunagar
# SPEC House, Parth Complex, Navrangpura, Nr. Swastik Cross Roads => SPEC House, Parth Complex, Navrangpura, NR Swastik Cross Road
# Naroda Road => Naroda Road
# ramdev nagar road => Ramdev Nagar Road
# ashram road => Ashram Road
# CHANAKYAPURI ROAD => CHANAKYAPURI ROAD
# CHANDLODIA STATION ROAD => CHANDLODIA STATION ROAD
# Nirnaynagar road => Nirnaynagar Road
# Gurukul Road, Vishram Marg => Gurukul Road, Vishram Marg
# Dr. Jivraj Mehta Road => Dr. Jivraj Mehta Road
# Dr. Hariprasad Desai Marg => Dr. Hariprasad Desai Marg
# Dr. Ambedkar Road => Dr. Ambedkar Road
# Dr. Vikram Sarabhai Road => Dr. Vikram Sarabhai Road
# New Nirnaynaga Road => New Nirnaynaga Road
# Akshar Avenue => Akshar Avenue
# Ramdevnagar road => Ramdevnagar Road
# 101, Paritosh Building, Usmanpura, Ashram Road => 101, Paritosh Building, Usmanpura, Ashram Road
# Satellite Road => Satellite Road
# Narol Sarkhej Road => Narol Sarkhej Road
# Surendra Mangaldas Road => Surendra Mangaldas Road
# shahpur => Shahpur
# Shreenath Nagar society => Shreenath Nagar Society
# Hirawadi road => Hirawadi Road
# Hirawadi => Hirawadi
# Sindhu bhawan road => Sindhu Bhawan Road
# Sindhu Bhawan Road => Sindhu Bhawan Road
# Sindhu Bhavan Road => Sindhu Bhavan Road
# Commerce College Road => Commerce College Road
# Lakhudi Circle => Lakhudi Circle
# Sargasan cross road => Sargasan Cross Road
# Sargasan Cross Road => Sargasan Cross Road
# Sargam Marg => Sargam Marg
# University Road => University Road
# Near NH 147 => Near NH 147
# Near Vyasvadi => Near Vyasvadi
# Near Balolnagar Cross Road => Near Balolnagar Cross Road
# Near Krishnabaug Cross Roads, Maninagar => Near Krishnabaug Cross Roads, Maninagar
# sidhubahavan road => Sidhubahavan Road
# Satya Marg => Satya Marg
# sbk society => SBK Society
# 100 Ft. Road => 100 Feet Road
# 100 ft Road => 100 Feet Road
# Heena Park Sosciety, Settellte => Heena Park Sosciety, Settellte
# Purshottam Malvankar Marg => Purshottam Malvankar Marg
# Nava Naroda Road => Nava Naroda Road
# Vijubhai Dave Marg => Vijubhai Dave Marg
# Ashram Road => Ashram Road
# mauraya gidc maha gujrat gidc road => Mauraya Gidc Maha Gujrat Gidc Road
# Shree Bapalal Dandwala Marg => Shree Bapalal Dandwala Marg
# Chimanlal Girdharlal Road => Chimanlal Girdharlal Road
# Gala Gym Khana Road => Gala Gym Khana Road
# Satyamev Vista Road => Satyamev Vista Road
# shreyas flyover service road => Shreyas Flyover Service Road
# Bapuangar => Bapuangar
# Mandir orad => Mandir Orad
# vijay char rasta => Vijay Char Road
# vijay cross road => Vijay Cross Road
# ACHER ROAD => ACHER ROAD
# Kasturba Gandhi Road => Kasturba Gandhi Road
# Drive-in Road => Drive-In Road
# kathwada GiDc road => Kathwada Gidc Road
# Nehru Bridge => Nehru Bridge
# St. Xavier's College Road => St. Xavier'S College Road
# Balol Nagar Road => Balol Nagar Road
# 2nd Floor, Aditya Complex, Opp kasturi Dining Hall, Paldi Cross Road, Paldi => 2Nd Floor, Aditya Complex, Opp Kasturi Dining Hall, Paldi Cross Road, Paldi
# 2nd Floor, Dev Arc Mall, Satellite Rd, Off S.G Highway, Near Iskcon Bridge => 2Nd Floor, Dev Arc Mall, Satellite Rd, Off S.G Highway, Near Iskcon Bridge
# Behind Ayodhyanagar => Behind Ayodhyanagar
# Shyam Sunder Row House, Behind Manav Mandir => Shyam Sunder Row House, Behind Manav Mandir
# Stadium Circle => Stadium Circle
# Stadium Commerce Six Roads => Stadium Commerce Six Road
# SM Road => SM Road
# CG Road => CG Road
# NEW ROAD NIRNAYNAGAR => NEW ROAD NIRNAYNAGAR
# S P Ring Road => S P Ring Road
# S G Highway => S G Highway
# B/H AryaVilla => B/H Aryavilla
# North Bopal => North Bopal
# Kotar pur-airport road => Kotar Pur-Airport Road
# Ranip => Ranip
# Opposite Sidi Saiyad Jali => Opposite Sidi Saiyad Jali
# Corporate Road => Corporate Road
# Gota Road => Gota Road
# Gota Road NH-147 => Gota Road NH-147
# Sola Road => Sola Road
# Thaltej Road => Thaltej Road
# Thaltej Underbridge => Thaltej Underbridge
# Bhagwat Nagar Society => Bhagwat Nagar Society
# Samartheshwar Mahadev Road => Samartheshwar Mahadev Road
# Sukharam Nagar Road => Sukharam Nagar Road
# Narmada Residency road => Narmada Residency Road
# CH Road => CH Road
# N. Palm Ave. #210 => N. Palm Avenue #210
# Paldi => Paldi
# Rambaug, Near Karnavati Club Road => Rambaug, Near Karnavati Club Road
# Kh road => Kh Road
# Sundarvan, Satellite Road => Sundarvan, Satellite Road
# FACTORY Road no.14 => FACTORY Road No.14
# SHIVAM  SQUAR => SHIVAM  SQUAR
# Sabarmati Riverfront Walkway, Usmanpura => Sabarmati Riverfront Walkway, Usmanpura
# Relief Road => Relief Road
# Pragatinagar => Pragatinagar
# Indroda Circle => Indroda Circle
# Khanpur => Khanpur
# Akhabarnagar Circle => Akhabarnagar Circle
# NH8C => NH8C
# NH8A => NH8A
# Sector 1 => Sector 1
# BalolNagar Cross Road => Balolnagar Cross Road
# Nr. Chandan Party Plot => NR Chandan Party Plot
# Jamalpur Road => Jamalpur Road
# Dutt society, Bhattha => Dutt Society, Bhattha
# Dutt Socity, Bhattha, Paldi => Dutt Socity, Bhattha, Paldi
# Shri Khandubhai Desai Marg => Shri Khandubhai Desai Marg
# Gulbai Tekra Road => Gulbai Tekra Road
# Nikol-Naroda Road => Nikol-Naroda Road
# Judges Bunglow Road => Judges Bunglow Road
# Judges Bungalow Road => Judges Bungalow Road
# Rabari colony road => Rabari Colony Road
# Navrang Society => Navrang Society
# Vatva phase -2 road => Vatva Phase -2 Road
# Vatva GIDC road => Vatva GIDC Road
# Vatva railway station road => Vatva Railway Station Road
# JUNA MADHUPURA ROAD => JUNA MADHUPURA ROAD
# Indira Bridge Circle . Apollo Complex => Indira Bridge Circle . Apollo Complex
# Uttamnagar, Ahmedabad => Uttamnagar, Ahmedabad
# Uttamnagar, Maninagar => Uttamnagar, Maninagar
# Asmita Society => Asmita Society
# Main bazar road road => Main Bazar Road Road
# Adalaj -sarkhej road => Adalaj -Sarkhej Road
# LD College of Engineering Internal Road => LD College Of Engineering Internal Road
# Kendriya Vihar Society => Kendriya Vihar Society
# Maninagar => Maninagar
# Tirupati Road => Tirupati Road
# Bopal - Sanand Bypass Road => Bopal - Sanand Bypass Road
# Hebatpur road => Hebatpur Road
# Hebatpur Road => Hebatpur Road
# Balvantrai Mehta Road => Balvantrai Mehta Road
# Sindhubhavan Road => Sindhubhavan Road
# Law Garden Road => Law Garden Road
# Anand nagar road => Anand Nagar Road
# Vatwa Road => Vatwa Road
# Bhadaj Cross Road, => Bhadaj Cross Road,
# Swami Vivekananda Road => Swami Vivekananda Road
# Swami Bapa Smruti Mandir Road => Swami Bapa Smruti Mandir Road
# Dada Bhagwan Trimandir, Ahmedabad - Kalol Highway, Adalaj, Gandhinagar, Gujarat, India  => Dada Bhagwan Trimandir, Ahmedabad - Kalol Highway, Adalaj, Gandhinagar, Gujarat, India
# Girdharnagar Road => Girdharnagar Road
# Lala Lajpat Rai Marg => Lala Lajpat Rai Marg
# Rakhial Road => Rakhial Road
# Airport Road => Airport Road
# Panjarapole Cross Roads => Panjarapole Cross Road
# Gujarat University Internal Road => Gujarat University Internal Road
# Gujarat => Gujarat
# Vijay Cross Roads => Vijay Cross Road
# NH8 => NH8
# Ghatlodia => Ghatlodia
# ASarwa => Asarwa
# C.G. Road => C.G. Road
# kh road => Kh Road
# Ahmedabad-Kalol Highway => Ahmedabad-Kalol Highway
# Dmart road / nikol naroda road => Dmart Road / Nikol Naroda Road
# tajpur road => Tajpur Road
# Nav-Sarjan School Road => Nav-Sarjan School Road

# %% [markdown]
# ## Problem with the Data - Postal Codes

# %%
filename = open("ahmedabad.osm", "r")

zip_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

zip_types = defaultdict(set)

expected_zip = {}

def audit_zip_codes(zip_types, zip_name, regex, expected_zip):
    m = regex.search(zip_name)
    if m:
        zip_type = m.group()
        if zip_type not in expected_zip:
             zip_types[zip_type].add(zip_name)

def is_zip_name(elem):
    return (elem.attrib['k'] == "addr:postcode")


def audit(filename, regex):
    for event, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag == "way" or elem.tag == "node":
            for tag in elem.iter("tag"):
                if is_zip_name(tag):
                    audit_zip_codes(zip_types, tag.attrib['v'], regex, expected_zip)
    pprint.pprint(dict(zip_types))

audit(filename, zip_type_re)
# Out:
# {'061': set(['380 061']),
#  '3': set(['3']),
#  '33026': set(['33026']),
#  '380001': set(['380001']),
#  '380003': set(['380003']),
#  '380004': set(['380004']),
#  '380005': set(['380005']),
#  '380006': set(['380006']),
#  '380007': set(['380007']),
#  '380008': set(['380008']),
#  '380009': set(['380009']),
#  '380013': set(['380013']),
#  '380014': set(['380014']),
#  '380015': set(['380015']),
#  '380021': set(['380021']),
#  '380023': set(['380023']),
#  '380024': set(['380024']),
#  '380026': set(['380026']),
#  '380027': set(['380027']),
#  '380028': set(['380028']),
#  '380043': set(['380043']),
#  '380051': set(['380051']),
#  '380052': set(['380052']),
#  '380054': set(['380054']),
#  '380058': set(['380058']),
#  '380059': set(['380059']),
#  '380060': set(['380060']),
#  '380061': set(['380061']),
#  '380063': set(['380063']),
#  '382006': set(['382006']),
#  '382007': set(['382007']),
#  '382009': set(['382009']),
#  '382210': set(['382210']),
#  '382345': set(['382345']),
#  '382350': set(['382350']),
#  '382405': set(['382405']),
#  '382418': set(['382418']),
#  '382421': set(['382421']),
#  '382424': set(['382424']),
#  '382440': set(['382440']),
#  '382445': set(['382445']),
#  '382475': set(['382475']),
#  '382480': set(['382480']),
#  '382481': set(['382481'])}

# %%
for zip_type, ways in zip_types.iteritems(): 
        for name in ways:
            if "-" in name:
                name = name.split("-")[0].strip()
            if "AZ" in name:
                name = name.split("AZ")[1].strip('AZ ')
            print name
# Out:
# 380013
# 380014
# 380015
# 382418
# 382481
# 382009
# 382475
# 382007
# 382006
# 380007
# 380006
# 3
# 382345
# 380061
# 382480
# 380005
# 380004
# 380003
# 380001
# 380043
# 380009
# 380008
# 380 061
# 382421
# 380028
# 382424
# 380024
# 380027
# 380026
# 380021
# 380023
# 382445
# 382440
# 382405
# 382210
# 380060
# 382350
# 380058
# 380059
# 380054
# 33026
# 380051
# 380052
# 380063

# %% [markdown]
# ## Problem with the Data - Phone Numbers

# %%
filename = open("ahmedabad.osm", "r")

phone_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

phone_types = defaultdict(set)

expected_zip = {}

def audit_phone_num(phone_types, phone_num, regex, expected_phone):
    m = regex.search(phone_num)
    if m:
        phone_type = m.group()
        if phone_type not in expected_zip:
             phone_types[phone_type].add(phone_num)

def is_phone_num(elem):
    return (elem.attrib['k'] == "phone")


def audit(filename, regex):
    for event, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag == "way" or elem.tag == "node":
            for tag in elem.iter("tag"):
                if is_phone_num(tag):
                    audit_phone_num(phone_types, tag.attrib['v'], regex, expected_zip)
    pprint.pprint(dict(phone_types))

audit(filename, phone_type_re)
# Out:
# {'0200': set(['+91793013 0200']),
#  '0201': set(['079 6619 0201']),
#  '0228': set(['0792740 0228']),
#  '0500/05/06/07/08/09': set(['+91 79 6190 0500/05/06/07/08/09']),
#  '079)39830036/37': set(['(079)39830036/37']),
#  '07922720605': set(['07922720605']),
#  '07922912990': set(['07922912990']),
#  '07925500007': set(['07925500007']),
#  '07926304000': set(['07926304000']),
#  '07926306752': set(['07926306752']),
#  '07926582130': set(['07926582130']),
#  '07927641100': set(['07927641100']),
#  '07965422223': set(['07965422223']),
#  '09016861000': set(['09016861000']),
#  '19151': set(['+91 93776 19151']),
#  '22239': set(['099099 22239']),
#  '2386': set(['079 2687 2386']),
#  '25556767': set(['+91 79 25556767']),
#  '26920057': set(['079 26920057']),
#  '29705588': set(['+91 79 29705588']),
#  '30912345': set(['+91 79 30912345']),
#  '38242': set(['093270 38242']),
#  '4032-7226': set(['(+91-79) 4032-7226']),
#  '41132': set(['+91 98250 41132']),
#  '5050': set(['079 4050 5050']),
#  '5151': set(['+91 79 6651 5151']),
#  '5222': set(['+91 79 2656 5222']),
#  '5741': set(['+91 79 2657 5741']),
#  '6464': set(['+91 79 2646 6464']),
#  '7096805450': set(['7096805450']),
#  '7181': set(['+91 79 2550 7181']),
#  '7621': set(['+91 79 2657 7621']),
#  '7926620059': set(['7926620059']),
#  '8369': set(['+9179 2657 8369']),
#  '84715': set(['+91 94262 84715']),
#  '855-553-4767': set(['855-553-4767']),
#  '8758637922': set(['+91 8758637922']),
#  '9054876866': set(['+91 9054876866']),
#  '91-79-26401554': set(['91-79-26401554']),
#  '91-79-40502232': set(['+91-79-40502232']),
#  '915752790': set(['915752790']),
#  '917801949128': set(['+917801949128']),
#  '917922167530': set(['+917922167530']),
#  '917922700585': set(['+917922700585']),
#  '917922864345': set(['+917922864345']),
#  '917923224006': set(['+917923224006']),
#  '917926314000': set(['917926314000']),
#  '917927472043': set(['+917927472043']),
#  '917927506819': set(['+917927506819']),
#  '917927550875': set(['+917927550875']),
#  '917965469992': set(['+917965469992']),
#  '919099958936': set(['+919099958936']),
#  '919375565533': set(['+919375565533']),
#  '919879566257': set(['+919879566257']),
#  '9375776800': set(['9375776800']),
#  '9429207992': set(['+91 79 2589 4542 / +91 9429207992']),
#  '99-98-264810': set(['+91 99-98-264810']),
#  '9909005694': set(['9909005694'])}

# %%
for phone_type, ways in phone_types.iteritems():
    for name in ways:
        if "+1 " in name:
            name = name.split("+1 ")[1].strip('+1 ')
        if "+" in name:
            name = name.split("+")[1].strip('+')
        if ";" in name:
            name = name.split(";")[0].strip()
        if name.startswith ("1-"): 
            name = name.strip("1-")
        if name.startswith ("1 "):
            name = name.strip("1 ")
        if "-" in name:
            name = name.replace("-", " ")
        if "(" in name:
            name = name.replace("(", "")
        if ")" in name:
            name = name.replace(")", "")
        if "." in name:
            name = name.replace(".", " ")
        if name.startswith("01"):
            name = name.strip("01")
        if name.startswith("Phone number "):
            name = name.strip("Phone number")
        if name.startswith("1 "):
            name = name.strip("1 ")
        if len(name) < 12:
            only_numbers = re.sub(r'\D', "", name)
            name = only_numbers[0:3] + " " + only_numbers[3:6] + " " + only_numbers[6:]
        if name.startswith(" "):
            name = name.replace(" ", "")
        if "x1" in name:
            name = name.strip("x1")
    
        print name
# Out:
# 0792740 0228
# 917922864345
# 917922700585
# 917965469992
# 099099 22239
# 090 168 61000
# 079 263 06752
# 91 79 40502232
# 079 654 22223
# 792 662 0059
# 079 229 12990
# 91 79 6651 5151
# 917927472043
# 91 99 98 264810
# 917801949128
# 937 577 6800
# 079 4050 5050
# 709 680 5450
# 079 265 82130
# 91 79 6190 0500/05/06/07/08/09
# 919375565533
# 91 79 26401554
# 9179 2657 8369
# 91 79 4032 7226
# 91 79 2657 7621
# 91 79 25556767
# 91793013 0200
# 079 2687 2386
# 91 94262 84715
# 91 93776 19151
# 917926314000
# 91 8758637922
# 91 79 29705588
# 917923224006
# 079 6619 0201
# 079 255 00007
# 079 227 20605
# 919879566257
# 07939830036/37
# 91 98250 41132
# 91 9054876866
# 917927506819
# 917927550875
# 093270 38242
# 990 900 5694
# 915 752 790
# 079 276 41100
# 91 79 2657 5741
# 91 79 2656 5222
# 079 263 04000
# 855 553 4767
# 91 79 2646 6464
# 917922167530
# 91 79 2589 4542 /
# 919099958936
# 91 79 2550 7181
# 079 26920057
# 91 79 30912345

# %% [markdown]
# ## Problematic Tags

# %%
filename = open("ahmedabad.osm", "r")

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        k = element.attrib['k']
        if re.search(lower, k):
            keys["lower"] += 1
        elif re.search(lower_colon, k):
            keys["lower_colon"] += 1
        elif re.search(problemchars, k):
            keys["problemchars"] += 1
        else:
            keys["other"] += 1
            
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

process_map(filename)
# Out:
# {'lower': 97364, 'lower_colon': 2004, 'other': 34, 'problemchars': 7}
